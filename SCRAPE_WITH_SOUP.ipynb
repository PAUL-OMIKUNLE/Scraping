# %% [markdown]
# ### Web Scraping WITH SOUP

# %%
# import dependencies
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## JOB LOCATION FOR LAGOS

# %%
url = "https://ng.indeed.com/jobs?q=python&l="

# %%
job=input('Job Location?')
# Out:
# Job Location?lagos

# %%
response = requests.get(url + job)
 jobs = results.find_all('div', class_='result')
 jobs = results.find_all('div', class_='row')
# job_titles = [job.find('h2').find('a').text.strip() for job in jobs]
# print(job_titles)

# %% [markdown]
# ## Accessing the HTML content

# %%
soup = bs(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <script src="//d3fw5vlhllyvee.cloudfront.net/s/bf71b51/en_NG.js" type="text/javascript"></script>
# <link href="//d3fw5vlhllyvee.cloudfront.net/s/4ed8717/jobsearch_all.css" rel="stylesheet" type="text/css"/>
# <link href="https://ng.indeed.com/rss?q=python&amp;l=lagos" rel="alternate" title="Python Jobs in Lagos" type="application/rss+xml"/>
# <link href="/m/jobs?q=python&amp;l=lagos" media="only screen and (max-width: 640px)" rel="alternate"/>
# <script type="text/javascript">
#
# if (typeof window['closureReadyCallbacks'] == 'undefined') {
# window['closureReadyCallbacks'] = [];
# }
#
# function call_when_jsall_loaded(cb) {
# if (window['closureReady']) {
# cb();
# } else {
# window['closureReadyCallbacks'].push(cb);
# }
# }
# </script>
# <meta content="1" name="ppstriptst"/>
# <script>
# var _scriptDownloadCount = 0;
# var _retryDownload = function() {
# ...

# %%
results = soup.find(id='resultsCol')

# %%
results
# Out:
# <td id="resultsCol">
# <div id="resultsColTopSpace"></div>
# <div class="messageContainer">
# <script type="text/javascript">
#       function setRefineByCookie(refineByTypes) {
#         var expires = new Date();
#         expires.setTime(expires.getTime() + (10 * 1000));
#         for (var i = 0; i < refineByTypes.length; i++) {
#           setCookie(refineByTypes[i], "1", expires);
#         }
#       }
#     </script>
# </div>
# <style type="text/css">
#     #increased_radius_result {
#         font-size: 1rem;
#         font-style: italic;
#     }
#     #original_radius_result{
#         font-size: 0.8125rem;
#         font-style: italic;
#         color: #666666;
#     }
# </style>
# <div class="resultsTop"><div class="mosaic-zone" id="mosaic-zone-aboveJobCards"><div class="mosaic mosaic-provider-serpreportjob" id="mosaic-provider-serpreportjob"><span><div class="mosaic-reportcontent-content"></div></span></div></div><script type="text/javascript">
#                 try {
# ...

# %%
jobs = results.find_all('div', class_='result')

# %%
jobs = results.find_all('div', class_='row')

# %%
len(jobs)
# Out:
# 15

# %%
jobs[0]
# Out:
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="825e126bf9d31085" data-tn-component="organicJob" id="p_825e126bf9d31085">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Bincom-Dev-Center/jobs/Tech-Internship-825e126bf9d31085?fccid=3683bdb6e692b8d4&amp;vjs=3" id="jl_825e126bf9d31085" onclick="setRefineByCookie([]); return rclk(this,jobmap[0],true,1);" onmousedown="return rclk(this,jobmap[0],1);" rel="noopener nofollow" target="_blank" title="Tech Internship (JANUARY 2021)">
# Tech Internship (JANUARY 2021)</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# Bincom Dev Center</span>
# </div>
# <div class="recJobLoc" data-rc-loc="Lagos" id="recJobLoc_825e126bf9d31085" style="display: none"></div>
# <span class="location accessible-contrast-color-location">Lagos</span>
# </div>
# <div class="salarySnippet salarySnippetDemphasizeholisticSalary">
# ...

# %%
job_titles = [job.find('h2').find('a').text.strip() for job in jobs]

# %%
job_titles
# Out:
# ['Tech Internship (JANUARY 2021)',
#  'Python Trainee Developer (Internship)',
#  'Full Stack Software Developer',
#  'Data Analyst',
#  'Python Developer',
#  'Software Engineer',
#  'Python Programmer',
#  'Senior Python Developer (Remote)',
#  'Test Analyst',
#  'Full Stack Developer (React)',
#  'Data Analyst',
#  'Web Developer',
#  'GAP IT Trainee Programme 2020 at Old Mutual Nigeria',
#  'Industrial Attachment Vacancies (Internship)',
#  'Business Intelligence Analyst']

# %%
title = jobs[3].find('h2')
title
# Out:
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=a926ead6236083a0&amp;fccid=dd616958bd9ddc12&amp;vjs=3" id="jl_a926ead6236083a0" onclick="setRefineByCookie([]); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="noopener nofollow" target="_blank" title="Data Analyst">
# Data Analyst</a>
# <span class="new">new</span></h2>

# %%
title_link = title.find('a')
title_link
# Out:
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=a926ead6236083a0&amp;fccid=dd616958bd9ddc12&amp;vjs=3" id="jl_a926ead6236083a0" onclick="setRefineByCookie([]); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="noopener nofollow" target="_blank" title="Data Analyst">
# Data Analyst</a>

# %%
title_link['href']
# Out:
# '/rc/clk?jk=a926ead6236083a0&fccid=dd616958bd9ddc12&vjs=3'

# %%
base_url = "https://ng.indeed.com"
job_url = base_url + title_link['href']
job_url
# Out:
# 'https://ng.indeed.com/rc/clk?jk=a926ead6236083a0&fccid=dd616958bd9ddc12&vjs=3'

# %% [markdown]
# ## REQUEST JOB URL

# %%
job_site = requests.get(job_url)
job_soup = bs(job_site.content)

# %% [markdown]
# #### GETTING THE TEXT

# %%
job_soup.text
# Out:
# '\n\nData Analyst - Lagos - Indeed.com\n\n\n\n\n\n\n\n\n\n\nSkip to main contentIndeed logoFind jobsCompany ReviewsCreate your CVSign inEmployers / Post JobSkip to main contentIndeed logoSign inFind jobsCompany ReviewsEmployersChange country\n\nwhatjob title, keywords, or companywherecity or stateFind jobsAdvanced Job SearchData Analyst-LagosSimilar Jobs\n\nData Analyst\nAnonymous Employer\nConsulting & Strategy\nAnonymous Employer\nConsulting & Strategy\nLagos|Full Time\nRecruitment|\nNGN Less than 75,000\n5d\n\nJob Summary\n\nSalary Budget: 200,000- 400,000\n\nMinimum Qualification: Degree\nExperience Level: Mid level\nExperience Length: 2 years\nJob Description/Requirements\n\nYears of experience: 2-3 years\n\nJob Responsibility:\nIdentify valuable data sources and automate collection processes\nUndertake pre-processing of structured and unstructured data\nAnalyze large amounts of information to discover trends and patterns\nBuild predictive models and machine-learning algorithms\
# ...
